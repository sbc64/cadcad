# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib 
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
import config
from cadCAD import configs
import matplotlib.pyplot as plt

# %matplotlib inline

exec_mode = ExecutionMode()
# Out:
# [{'T': range(0, 50), 'N': 1, 'M': [{}]}]

# %%
# Run Cad^2

first_config = configs # only contains config1
single_proc_ctx = ExecutionContext(context=exec_mode.single_proc)
run = Executor(exec_context=single_proc_ctx, configs=first_config)

raw_result, tensor_field = run.execute()
df = pd.DataFrame(raw_result)
df.set_index(['run', 'timestep', 'substep'])
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: single_proc: [<cadCAD.configuration.Configuration object at 0x11f1ba978>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x11f1ba978>]
#                       target_rate  target_price  market_price
# run timestep substep
# 1   0        0           0.000000      1.000000           1.0
#     1        1           0.000000      1.000000           1.0
#     2        1           0.000000      1.000000           1.0
#     3        1           0.000000      1.000000           1.0
#     4        1           0.000000      1.000000           1.0
#     5        1           0.000000      1.000000           1.0
#     6        1           0.000000      1.000000           1.1
#     7        1           0.090909      1.000000           1.2
#     8        1           0.166667      1.090909           1.3
#     9        1           0.160839      1.257576           1.4
#     10       1           0.101732      1.418415           1.5
#     11       1           0.054390      1.520147           1.5
#     12       1          -0.013431      1.574537           1.5
#     13       1          -0.049691      1.561106           1.5
#     14       1          -0.040737      1.511415           1.5
#     15       1          -0.007610      1.470677           1.5
#     16       1           0.019548      1.463068           1.5
#     17       1           0.024621      1.482616           1.5
#     18       1           0.011589      1.507238           1.5
#     19       1          -0.004825      1.518827           1.5
#     20       1          -0.012551      1.514002           1.5
#     21       1          -0.009335      1.501451           1.5
#     22       1          -0.000967      1.492116           1.5
#     23       1           0.005256      1.491149           1.5
#     24       1           0.005901      1.496405           1.5
#     25       1           0.002397      1.502306           1.5
#     26       1          -0.001537      1.504702           1.5
#     27       1          -0.003135      1.503165           1.5
#     28       1          -0.002110      1.500030           1.5
#     29       1          -0.000020      1.497920           1.5
#     30       1           0.001387      1.497900           1.5
#     31       1           0.001400      1.499287           1.5
#     32       1           0.000476      1.500687           1.5
#     33       1          -0.000458      1.501162           1.5
#     34       1          -0.000775      1.500705           1.5
#     35       1          -0.000470      1.499930           1.5
#     36       1           0.000047      1.499460           1.5
#     37       1           0.000360      1.499507           1.5
#     38       1           0.000329      1.499867           1.5
#     39       1           0.000089      1.500196           1.5
#     40       1          -0.000130      1.500284           1.5
#     41       1          -0.000190      1.500154           1.5
#     42       1          -0.000103      1.499964           1.5
#     43       1           0.000024      1.499862           1.5
#     44       1           0.000092      1.499885           1.5
#     45       1           0.000076      1.499978           1.5
#     46       1           0.000015      1.500054           1.5
#     47       1          -0.000036      1.500069           1.5
#     48       1          -0.000046      1.500033           1.5
#     49       1          -0.000022      1.499987           1.5
#     50       1           0.000009      1.499965           1.5

# %%
df.plot('timestep', ['market_price', 'target_price', 'target_rate'], grid=True, 
        colormap = 'winter',
        xticks=list(df['timestep'].drop_duplicates()), 
        yticks=list(range(int(1+(df['market_price']+df['target_price']).max()))));
