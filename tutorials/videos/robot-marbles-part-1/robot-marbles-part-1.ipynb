# %% [markdown]
# # cadCAD Template: Robot and the Marbles
#
# ![](images/Overview.jpeg)
# ![](images/Mech.jpeg)
# ![](images/equations.png)

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib 
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
import config
from cadCAD import configs
import matplotlib.pyplot as plt

# %matplotlib inline

exec_mode = ExecutionMode()
# Out:
# [{'T': range(0, 10), 'N': 1, 'M': [{}]}]

# %%
# Run Cad^2

first_config = configs # only contains config1
single_proc_ctx = ExecutionContext(context=exec_mode.single_proc)
run = Executor(exec_context=single_proc_ctx, configs=first_config)

raw_result, tensor_field = run.execute()
print(raw_result)
df = pd.DataFrame(raw_result)
df.set_index(['run', 'timestep', 'substep'])
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: single_proc: [<cadCAD.configuration.Configuration object at 0x11ca9ca90>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x11ca9ca90>]
# [{'box_A': 10, 'box_B': 0, 'run': 1, 'substep': 0, 'timestep': 0}, {'box_A': 9, 'box_B': 1, 'run': 1, 'substep': 1, 'timestep': 1}, {'box_A': 8, 'box_B': 2, 'run': 1, 'substep': 1, 'timestep': 2}, {'box_A': 7, 'box_B': 3, 'run': 1, 'substep': 1, 'timestep': 3}, {'box_A': 6, 'box_B': 4, 'run': 1, 'substep': 1, 'timestep': 4}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 5}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 6}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 7}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 8}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 9}, {'box_A': 5, 'box_B': 5, 'run': 1, 'substep': 1, 'timestep': 10}]
#                       box_A  box_B
# run timestep substep
# 1   0        0           10      0
#     1        1            9      1
#     2        1            8      2
#     3        1            7      3
#     4        1            6      4
#     5        1            5      5
#     6        1            5      5
#     7        1            5      5
#     8        1            5      5
#     9        1            5      5
#     10       1            5      5

# %%
df.plot('timestep', ['box_A', 'box_B'], grid=True, 
        colormap = 'RdYlGn',
        xticks=list(df['timestep'].drop_duplicates()), 
        yticks=list(range(1+(df['box_A']+df['box_B']).max())));

# %%
import config2
first_config = configs # only contains config1
single_proc_ctx = ExecutionContext(context=exec_mode.single_proc)
run = Executor(exec_context=single_proc_ctx, configs=first_config)

raw_result, tensor_field = run.execute()
df2 = pd.DataFrame(raw_result)
df2.set_index(['run', 'timestep', 'substep'])
# Out:
# [{'T': range(0, 10), 'N': 1, 'M': [{}]}]
#
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: single_proc: [<cadCAD.configuration.Configuration object at 0x11ca9ca90>, <cadCAD.configuration.Configuration object at 0x11f8e24a8>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x11ca9ca90>, <cadCAD.configuration.Configuration object at 0x11f8e24a8>]
#                       box_A  box_B
# run timestep substep
# 1   0        0           11      0
#     1        1           10      1
#     2        1            9      2
#     3        1            8      3
#     4        1            7      4
#     5        1            6      5
#     6        1            5      6
#     7        1            6      5
#     8        1            5      6
#     9        1            6      5
#     10       1            5      6

# %%
df2.plot('timestep', ['box_A', 'box_B'], grid=True, 
        colormap = 'RdYlGn',
        xticks=list(df['timestep'].drop_duplicates()), 
        yticks=list(range(1+(df['box_A']+df['box_B']).max())));
